# %% [markdown]
# # Final Exercise - Putting it All Together
#
# In this last exercise, you'll write a full ETL pipeline for the GDP data. That means you'll extract the World Bank data, transform the data, and load the data all in one go. In other words, you'll want one Python script that can do the entire process.
#
# Why would you want to do this? Imagine working for a company that creates new data every day. As new data comes in, you'll want to write software that periodically and automatically extracts, transforms, and loads the data.
#
# To give you a sense for what this is like, you'll extract the GDP data one line at a time. You'll then transform that line of data and load the results into a SQLite database. The code in this exercise is somewhat tricky.
#
# Here is an explanation of how this Jupyter notebook is organized:
# 1. The first cell connects to a SQLite database called worldbank.db and creates a table to hold the gdp data. You do not need to do anything in this code cell other than executing the cell.
# 2. The second cell has a function called extract_line(). You don't need to do anything in this code cell either besides executing the cell. This function is a [Python generator](https://wiki.python.org/moin/Generators). You don't need to understand how this works in order to complete the exercise. Essentially, a generator is like a regular function except instead of a return statement, a generator has a yield statement. Generators allow you to use functions in a for loop. In essence, this function will allow you to read in a data file one line at a time, run a transformation on that row of data, and then move on to the next row in the file.
# 3. The third cell contains a function called transform_indicator_data(). This function receives a line from the csv file and transforms the data in preparation for a load step.
# 4. The fourth cell contains a function called load_indicator_data(), which loads the trasnformed data into the gdp table in the worldbank.db database.
# 5. The fifth cell runs the ETL pipeilne
# 6. The sixth cell runs a query against the database to make sure everything worked correctly.
#
# You'll need to modify the third and fourth cells.

# %%
# run this cell to create a database and a table, called gdp, to hold the gdp data
# You do not need to change anything in this code cell

import sqlite3

# connect to the database
# the database file will be worldbank.db
# note that sqlite3 will create this database file if it does not exist already
conn = sqlite3.connect('worldbank.db')

# get a cursor
cur = conn.cursor()

# drop the test table in case it already exists
cur.execute("DROP TABLE IF EXISTS gdp")

# create the test table including project_id as a primary key
cur.execute("CREATE TABLE gdp (countryname TEXT, countrycode TEXT, year INTEGER, gdp REAL, PRIMARY KEY (countrycode, year));")

conn.commit()
conn.close()

# %%
# Generator for reading in one line at a time
# generators are useful for data sets that are too large to fit in RAM
# You do not need to change anything in this code cell
def extract_lines(file):
    while True:
        line = file.readline()
        if not line:
            break
        yield line

# %%
# TODO: fill out the code wherever you find a TODO in this cell
# This function has two inputs:
#   data, which is a row of data from the gdp csv file
#   colnames, which is a list of column names from the csv file
# The output should be a list of [countryname, countrycode, year, gdp] values
# In other words, the output would look like:
# [[Aruba, ABW, 1994, 1.330168e+09], [Aruba, ABW, 1995, 1.320670e+09], ...]
#

import pandas as pd
import numpy as np
import sqlite3

# transform the indicator data
def transform_indicator_data(data, colnames):
    
    # get rid of quote marks
    for i, datum in enumerate(data):
        data[i] = datum.replace('"','')
    
    # TODO: the data variable contains a list of data in the form [countryname, countrycode, 1960, 1961, 1962,...]
    # since this is the format of the data in the csv file. Extract the countryname from the list 
    # and put the result in the country variable
    country = data[0]
    
    # these are "countryname" values that are not actually countries
    non_countries = ['World',
     'High income',
     'OECD members',
     'Post-demographic dividend',
     'IDA & IBRD total',
     'Low & middle income',
     'Middle income',
     'IBRD only',
     'East Asia & Pacific',
     'Europe & Central Asia',
     'North America',
     'Upper middle income',
     'Late-demographic dividend',
     'European Union',
     'East Asia & Pacific (excluding high income)',
     'East Asia & Pacific (IDA & IBRD countries)',
     'Euro area',
     'Early-demographic dividend',
     'Lower middle income',
     'Latin America & Caribbean',
     'Latin America & the Caribbean (IDA & IBRD countries)',
     'Latin America & Caribbean (excluding high income)',
     'Europe & Central Asia (IDA & IBRD countries)',
     'Middle East & North Africa',
     'Europe & Central Asia (excluding high income)',
     'South Asia (IDA & IBRD)',
     'South Asia',
     'Arab World',
     'IDA total',
     'Sub-Saharan Africa',
     'Sub-Saharan Africa (IDA & IBRD countries)',
     'Sub-Saharan Africa (excluding high income)',
     'Middle East & North Africa (excluding high income)',
     'Middle East & North Africa (IDA & IBRD countries)',
     'Central Europe and the Baltics',
     'Pre-demographic dividend',
     'IDA only',
     'Least developed countries: UN classification',
     'IDA blend',
     'Fragile and conflict affected situations',
     'Heavily indebted poor countries (HIPC)',
     'Low income',
     'Small states',
     'Other small states',
     'Not classified',
     'Caribbean small states',
     'Pacific island small states']
    
    # filter out country name values that are in the above list
    if country not in non_countries:
        
        # In this section, you'll convert the single row of data into a data frame
        # The advantage of converting a single row of data into a data frame is that you can
        # re-use code from earlier in the lesson to clean the data
        
        # TODO: convert the data variable into a numpy array
        # Use the ndmin=2 option
        data_array = np.array(data, ndmin=2)
        
        # TODO: reshape the data_array so that it is one row and 63 columns
        data_array.reshape(1,63)
        
        # TODO: convert the data_array variable into a pandas dataframe
        # Note that you can specify the column names as well using the colnames variable
        # Also, replace all empty strings in the dataframe with nan (HINT: Use the replace module and np.nan)
        df = pd.DataFrame(data_array, columns=colnames)
        df = df.replace('', np.nan)
        
        # TODO: Drop the 'Indicator Name' and 'Indicator Code' columns
        df.drop(columns=['Indicator Name', 'Indicator Code'], inplace=True, axis=1)

        # TODO: Reshape the data sets so that they are in long format
        # The id_vars should be Country Name and Country Code
        # You can name the variable column year and the value column gdp
        # HINT: Use the pandas melt() method
        # HINT: This was already done in a previous exercise
        df_melt = pd.melt(df, id_vars=['Country Name', 'Country Code'], var_name='year', value_name='gdp')
        
        # TODO: Iterate through the rows in df_melt
        # For each row, extract the country, countrycode, year, and gdp values into a list like this:
        #     [country, countrycode, year, gdp]
        # If the gdp value is not null, append the row (in the form of a list) to the results variable
        # Finally, return the results list after iterating through the df_melt data
        # HINT: the iterrows() method would be useful
        # HINT: to check if gdp is equal to nan, you might want to convert gdp to a string and compare to the
        #       string 'nan
        results=[]
     
        for index, row in df_melt.iterrows():
            row_list = row.tolist()
            gdp = str(row_list[-1])
            
            if gdp != np.nan:
                results.append(row_list)
            else:
                pass
                
            
            

        return results

# %%
# TODO: fill out the code wherever you find a TODO in this cell
# This function loads data into the gdp table of the worldbank.db database
# The input is a list of data outputted from the transformation step that looks like this:
# [[Aruba, ABW, 1994, 1.330168e+09], [Aruba, ABW, 1995, 1.320670e+09], ...]

# The function does not return anything. Instead, the function iterates through the input and inserts each
# value into the gdp data set.

def load_indicator_data(results):
    
    # TODO: connect to the worldbank.db database using the sqlite3 library
    conn = sqlite3.connect('worldbank.db')
    
    # TODO: create a cursor object
    cur = conn.cursor()
    
    if results:
        
        # iterate through the results variable and insert each result into the gdp table
        for result in results:
            
            # TODO: extract the countryname, countrycode, year, and gdp from each iteration
            countryname, countrycode, year, gdp = result

            # TODO: prepare a query to insert a countryname, countrycode, year, gdp value
            sql_string = 'INSERT INTO gdp (countryname, countrycode, year, gdp) VALUES ("{}", "{}", {}, {});'.format(countryname, countrycode, year, gdp)
            # connect to database and execute query
            try:
                cur.execute(sql_string)
            # print out any errors (like if the primary key constraint is violated)
            except Exception as e:
                print('error occurred:', e, result)
    
    # commit changes and close the connection
    conn.commit()
    conn.close()
    
    return None

# %%
# Execute this code cell to run the ETL pipeline
# You do not need to change anything in this cell

# open the data file
with open('../data/gdp_data.csv') as f:
    # execute the generator to read in the file line by line
    for line in extract_lines(f):
        # split the comma separated values
        data = line.split(',')
        # check the length of the line because the first four lines of the csv file are not data
        if len(data) == 63:
            # check if the line represents column names
            if data[0] == '"Country Name"':
                colnames = []
                # get rid of quote marks in the results to make the data easier to work with
                for i, datum in enumerate(data):
                    colnames.append(datum.replace('"',''))
            else:
                # transform and load the line of indicator data
                results = transform_indicator_data(data, colnames)
                load_indicator_data(results)
# Out:
# error occurred: no such column: nan ['Aruba', 'ABW', '1960', nan]
# error occurred: no such column: nan ['Aruba', 'ABW', '1961', nan]
# error occurred: no such column: nan ['Aruba', 'ABW', '1962', nan]
# error occurred: no such column: nan ['Aruba', 'ABW', '1963', nan]
# error occurred: no such column: nan ['Aruba', 'ABW', '1964', nan]
# error occurred: no such column: nan ['Aruba', 'ABW', '1965', nan]
# error occurred: no such column: nan ['Aruba', 'ABW', '1966', nan]
# error occurred: no such column: nan ['Aruba', 'ABW', '1967', nan]
# error occurred: no such column: nan ['Aruba', 'ABW', '1968', nan]
# error occurred: no such column: nan ['Aruba', 'ABW', '1969', nan]
# error occurred: no such column: nan ['Aruba', 'ABW', '1970', nan]
# error occurred: no such column: nan ['Aruba', 'ABW', '1971', nan]
# error occurred: no such column: nan ['Aruba', 'ABW', '1972', nan]
# error occurred: no such column: nan ['Aruba', 'ABW', '1973', nan]
# error occurred: no such column: nan ['Aruba', 'ABW', '1974', nan]
# error occurred: no such column: nan ['Aruba', 'ABW', '1975', nan]
# error occurred: no such column: nan ['Aruba', 'ABW', '1976', nan]
# error occurred: no such column: nan ['Aruba', 'ABW', '1977', nan]
# error occurred: no such column: nan ['Aruba', 'ABW', '1978', nan]
# error occurred: no such column: nan ['Aruba', 'ABW', '1979', nan]
# error occurred: no such column: nan ['Aruba', 'ABW', '1980', nan]
# error occurred: no such column: nan ['Aruba', 'ABW', '1981', nan]
# error occurred: no such column: nan ['Aruba', 'ABW', '1982', nan]
# error occurred: no such column: nan ['Aruba', 'ABW', '1983', nan]
# error occurred: no such column: nan ['Aruba', 'ABW', '1984', nan]
# error occurred: no such column: nan ['Aruba', 'ABW', '1985', nan]
# error occurred: no such column: nan ['Aruba', 'ABW', '1986', nan]
# error occurred: no such column: nan ['Aruba', 'ABW', '1987', nan]
# error occurred: no such column: nan ['Aruba', 'ABW', '1988', nan]
# error occurred: no such column: nan ['Aruba', 'ABW', '1989', nan]
# error occurred: no such column: nan ['Aruba', 'ABW', '1990', nan]
# error occurred: no such column: nan ['Aruba', 'ABW', '1991', nan]
# error occurred: no such column: nan ['Aruba', 'ABW', '1992', nan]
# error occurred: no such column: nan ['Aruba', 'ABW', '1993', nan]
# error occurred: no such column: nan ['Aruba', 'ABW', '2012', nan]
# error occurred: no such column: nan ['Aruba', 'ABW', '2013', nan]
# error occurred: no such column: nan ['Aruba', 'ABW', '2014', nan]
# error occurred: no such column: nan ['Aruba', 'ABW', '2015', nan]
# error occurred: no such column: nan ['Aruba', 'ABW', '2016', nan]
# error occurred: no such column: nan ['Aruba', 'ABW', '2017', nan]
# error occurred: near ",": syntax error ['Aruba', 'ABW', '\n', '\n']
# error occurred: no such column: nan ['Afghanistan', 'AFG', '1982', nan]
# error occurred: no such column: nan ['Afghanistan', 'AFG', '1983', nan]
# error occurred: no such column: nan ['Afghanistan', 'AFG', '1984', nan]
# error occurred: no such column: nan ['Afghanistan', 'AFG', '1985', nan]
# error occurred: no such column: nan ['Afghanistan', 'AFG', '1986', nan]
# error occurred: no such column: nan ['Afghanistan', 'AFG', '1987', nan]
# error occurred: no such column: nan ['Afghanistan', 'AFG', '1988', nan]
# error occurred: no such column: nan ['Afghanistan', 'AFG', '1989', nan]
# error occurred: no such column: nan ['Afghanistan', 'AFG', '1990', nan]
# error occurred: no such column: nan ['Afghanistan', 'AFG', '1991', nan]
# error occurred: no such column: nan ['Afghanistan', 'AFG', '1992', nan]
# error occurred: no such column: nan ['Afghanistan', 'AFG', '1993', nan]
# error occurred: no such column: nan ['Afghanistan', 'AFG', '1994', nan]
# error occurred: no such column: nan ['Afghanistan', 'AFG', '1995', nan]
# error occurred: no such column: nan ['Afghanistan', 'AFG', '1996', nan]
# error occurred: no such column: nan ['Afghanistan', 'AFG', '1997', nan]
# error occurred: no such column: nan ['Afghanistan', 'AFG', '1998', nan]
# error occurred: no such column: nan ['Afghanistan', 'AFG', '1999', nan]
# error occurred: no such column: nan ['Afghanistan', 'AFG', '2000', nan]
# error occurred: near ",": syntax error ['Afghanistan', 'AFG', '\n', '\n']
# error occurred: no such column: nan ['Angola', 'AGO', '1960', nan]
# error occurred: no such column: nan ['Angola', 'AGO', '1961', nan]
# error occurred: no such column: nan ['Angola', 'AGO', '1962', nan]
# error occurred: no such column: nan ['Angola', 'AGO', '1963', nan]
# error occurred: no such column: nan ['Angola', 'AGO', '1964', nan]
# error occurred: no such column: nan ['Angola', 'AGO', '1965', nan]
# error occurred: no such column: nan ['Angola', 'AGO', '1966', nan]
# error occurred: no such column: nan ['Angola', 'AGO', '1967', nan]
# error occurred: no such column: nan ['Angola', 'AGO', '1968', nan]
# error occurred: no such column: nan ['Angola', 'AGO', '1969', nan]
# error occurred: no such column: nan ['Angola', 'AGO', '1970', nan]
# error occurred: no such column: nan ['Angola', 'AGO', '1971', nan]
# error occurred: no such column: nan ['Angola', 'AGO', '1972', nan]
# error occurred: no such column: nan ['Angola', 'AGO', '1973', nan]
# error occurred: no such column: nan ['Angola', 'AGO', '1974', nan]
# error occurred: no such column: nan ['Angola', 'AGO', '1975', nan]
# error occurred: no such column: nan ['Angola', 'AGO', '1976', nan]
# error occurred: no such column: nan ['Angola', 'AGO', '1977', nan]
# error occurred: no such column: nan ['Angola', 'AGO', '1978', nan]
# error occurred: no such column: nan ['Angola', 'AGO', '1979', nan]
# error occurred: no such column: nan ['Angola', 'AGO', '1991', nan]
# error occurred: no such column: nan ['Angola', 'AGO', '1992', nan]
# error occurred: no such column: nan ['Angola', 'AGO', '1993', nan]
# error occurred: near ",": syntax error ['Angola', 'AGO', '\n', '\n']
# error occurred: no such column: nan ['Albania', 'ALB', '1960', nan]
# error occurred: no such column: nan ['Albania', 'ALB', '1961', nan]
# error occurred: no such column: nan ['Albania', 'ALB', '1962', nan]
# error occurred: no such column: nan ['Albania', 'ALB', '1963', nan]
# error occurred: no such column: nan ['Albania', 'ALB', '1964', nan]
# error occurred: no such column: nan ['Albania', 'ALB', '1965', nan]
# error occurred: no such column: nan ['Albania', 'ALB', '1966', nan]
# error occurred: no such column: nan ['Albania', 'ALB', '1967', nan]
# error occurred: no such column: nan ['Albania', 'ALB', '1968', nan]
# error occurred: no such column: nan ['Albania', 'ALB', '1969', nan]
# error occurred: no such column: nan ['Albania', 'ALB', '1970', nan]
# error occurred: no such column: nan ['Albania', 'ALB', '1971', nan]
# error occurred: no such column: nan ['Albania', 'ALB', '1972', nan]
# error occurred: no such column: nan ['Albania', 'ALB', '1973', nan]
# error occurred: no such column: nan ['Albania', 'ALB', '1974', nan]
# error occurred: no such column: nan ['Albania', 'ALB', '1975', nan]
# error occurred: no such column: nan ['Albania', 'ALB', '1976', nan]
# error occurred: no such column: nan ['Albania', 'ALB', '1977', nan]
# error occurred: no such column: nan ['Albania', 'ALB', '1978', nan]
# error occurred: no such column: nan ['Albania', 'ALB', '1979', nan]
# error occurred: no such column: nan ['Albania', 'ALB', '1980', nan]
# error occurred: no such column: nan ['Albania', 'ALB', '1981', nan]
# error occurred: no such column: nan ['Albania', 'ALB', '1982', nan]
# error occurred: no such column: nan ['Albania', 'ALB', '1983', nan]
# error occurred: near ",": syntax error ['Albania', 'ALB', '\n', '\n']
# error occurred: no such column: nan ['Andorra', 'AND', '1960', nan]
# error occurred: no such column: nan ['Andorra', 'AND', '1961', nan]
# error occurred: no such column: nan ['Andorra', 'AND', '1962', nan]
# error occurred: no such column: nan ['Andorra', 'AND', '1963', nan]
# error occurred: no such column: nan ['Andorra', 'AND', '1964', nan]
# error occurred: no such column: nan ['Andorra', 'AND', '1965', nan]
# error occurred: no such column: nan ['Andorra', 'AND', '1966', nan]
# error occurred: no such column: nan ['Andorra', 'AND', '1967', nan]
# error occurred: no such column: nan ['Andorra', 'AND', '1968', nan]
# error occurred: no such column: nan ['Andorra', 'AND', '1969', nan]
# error occurred: near ",": syntax error ['Andorra', 'AND', '\n', '\n']
# error occurred: no such column: nan ['United Arab Emirates', 'ARE', '1960', nan]
# error occurred: no such column: nan ['United Arab Emirates', 'ARE', '1961', nan]
# error occurred: no such column: nan ['United Arab Emirates', 'ARE', '1962', nan]
# error occurred: no such column: nan ['United Arab Emirates', 'ARE', '1963', nan]
# error occurred: no such column: nan ['United Arab Emirates', 'ARE', '1964', nan]
# error occurred: no such column: nan ['United Arab Emirates', 'ARE', '1965', nan]
# error occurred: no such column: nan ['United Arab Emirates', 'ARE', '1966', nan]
# error occurred: no such column: nan ['United Arab Emirates', 'ARE', '1967', nan]
# error occurred: no such column: nan ['United Arab Emirates', 'ARE', '1968', nan]
# error occurred: no such column: nan ['United Arab Emirates', 'ARE', '1969', nan]
# error occurred: no such column: nan ['United Arab Emirates', 'ARE', '1970', nan]
# error occurred: no such column: nan ['United Arab Emirates', 'ARE', '1971', nan]
# error occurred: no such column: nan ['United Arab Emirates', 'ARE', '1972', nan]
# error occurred: no such column: nan ['United Arab Emirates', 'ARE', '1973', nan]
# error occurred: no such column: nan ['United Arab Emirates', 'ARE', '1974', nan]
# error occurred: near ",": syntax error ['United Arab Emirates', 'ARE', '\n', '\n']
# error occurred: no such column: nan ['Argentina', 'ARG', '1960', nan]
# error occurred: no such column: nan ['Argentina', 'ARG', '1961', nan]
# error occurred: no such column: nan ['Argentina', 'ARG', '1962', nan]
# error occurred: no such column: nan ['Argentina', 'ARG', '1963', nan]
# error occurred: no such column: nan ['Argentina', 'ARG', '1964', nan]
# error occurred: no such column: nan ['Argentina', 'ARG', '1965', nan]
# error occurred: no such column: nan ['Argentina', 'ARG', '1966', nan]
# error occurred: no such column: nan ['Argentina', 'ARG', '1967', nan]
# error occurred: no such column: nan ['Argentina', 'ARG', '1968', nan]
# error occurred: no such column: nan ['Argentina', 'ARG', '1969', nan]
# error occurred: no such column: nan ['Argentina', 'ARG', '1970', nan]
# error occurred: near ",": syntax error ['Argentina', 'ARG', '\n', '\n']
# error occurred: no such column: nan ['Armenia', 'ARM', '1960', nan]
# error occurred: no such column: nan ['Armenia', 'ARM', '1961', nan]
# error occurred: no such column: nan ['Armenia', 'ARM', '1962', nan]
# error occurred: no such column: nan ['Armenia', 'ARM', '1963', nan]
# error occurred: no such column: nan ['Armenia', 'ARM', '1964', nan]
# error occurred: no such column: nan ['Armenia', 'ARM', '1965', nan]
# error occurred: no such column: nan ['Armenia', 'ARM', '1966', nan]
# error occurred: no such column: nan ['Armenia', 'ARM', '1967', nan]
# error occurred: no such column: nan ['Armenia', 'ARM', '1968', nan]
# error occurred: no such column: nan ['Armenia', 'ARM', '1969', nan]
# error occurred: no such column: nan ['Armenia', 'ARM', '1970', nan]
# error occurred: no such column: nan ['Armenia', 'ARM', '1971', nan]
# error occurred: no such column: nan ['Armenia', 'ARM', '1972', nan]
# error occurred: no such column: nan ['Armenia', 'ARM', '1973', nan]
# error occurred: no such column: nan ['Armenia', 'ARM', '1974', nan]
# error occurred: no such column: nan ['Armenia', 'ARM', '1975', nan]
# error occurred: no such column: nan ['Armenia', 'ARM', '1976', nan]
# error occurred: no such column: nan ['Armenia', 'ARM', '1977', nan]
# error occurred: no such column: nan ['Armenia', 'ARM', '1978', nan]
# error occurred: no such column: nan ['Armenia', 'ARM', '1979', nan]
# error occurred: no such column: nan ['Armenia', 'ARM', '1980', nan]
# error occurred: no such column: nan ['Armenia', 'ARM', '1981', nan]
# error occurred: no such column: nan ['Armenia', 'ARM', '1982', nan]
# error occurred: no such column: nan ['Armenia', 'ARM', '1983', nan]
# error occurred: no such column: nan ['Armenia', 'ARM', '1984', nan]
# error occurred: no such column: nan ['Armenia', 'ARM', '1985', nan]
# error occurred: no such column: nan ['Armenia', 'ARM', '1986', nan]
# error occurred: no such column: nan ['Armenia', 'ARM', '1987', nan]
# error occurred: no such column: nan ['Armenia', 'ARM', '1988', nan]
# error occurred: no such column: nan ['Armenia', 'ARM', '1989', nan]
# error occurred: near ",": syntax error ['Armenia', 'ARM', '\n', '\n']
# error occurred: no such column: nan ['American Samoa', 'ASM', '1960', nan]
# error occurred: no such column: nan ['American Samoa', 'ASM', '1961', nan]
# error occurred: no such column: nan ['American Samoa', 'ASM', '1962', nan]
# error occurred: no such column: nan ['American Samoa', 'ASM', '1963', nan]
# error occurred: no such column: nan ['American Samoa', 'ASM', '1964', nan]
# error occurred: no such column: nan ['American Samoa', 'ASM', '1965', nan]
# error occurred: no such column: nan ['American Samoa', 'ASM', '1966', nan]
# error occurred: no such column: nan ['American Samoa', 'ASM', '1967', nan]
# error occurred: no such column: nan ['American Samoa', 'ASM', '1968', nan]
# error occurred: no such column: nan ['American Samoa', 'ASM', '1969', nan]
# error occurred: no such column: nan ['American Samoa', 'ASM', '1970', nan]
# error occurred: no such column: nan ['American Samoa', 'ASM', '1971', nan]
# error occurred: no such column: nan ['American Samoa', 'ASM', '1972', nan]
# error occurred: no such column: nan ['American Samoa', 'ASM', '1973', nan]
# error occurred: no such column: nan ['American Samoa', 'ASM', '1974', nan]
# error occurred: no such column: nan ['American Samoa', 'ASM', '1975', nan]
# error occurred: no such column: nan ['American Samoa', 'ASM', '1976', nan]
# error occurred: no such column: nan ['American Samoa', 'ASM', '1977', nan]
# error occurred: no such column: nan ['American Samoa', 'ASM', '1978', nan]
# error occurred: no such column: nan ['American Samoa', 'ASM', '1979', nan]
# error occurred: no such column: nan ['American Samoa', 'ASM', '1980', nan]
# error occurred: no such column: nan ['American Samoa', 'ASM', '1981', nan]
# error occurred: no such column: nan ['American Samoa', 'ASM', '1982', nan]
# error occurred: no such column: nan ['American Samoa', 'ASM', '1983', nan]
# error occurred: no such column: nan ['American Samoa', 'ASM', '1984', nan]
# error occurred: no such column: nan ['American Samoa', 'ASM', '1985', nan]
# error occurred: no such column: nan ['American Samoa', 'ASM', '1986', nan]
# error occurred: no such column: nan ['American Samoa', 'ASM', '1987', nan]
# error occurred: no such column: nan ['American Samoa', 'ASM', '1988', nan]
# error occurred: no such column: nan ['American Samoa', 'ASM', '1989', nan]
# error occurred: no such column: nan ['American Samoa', 'ASM', '1990', nan]
# error occurred: no such column: nan ['American Samoa', 'ASM', '1991', nan]
# error occurred: no such column: nan ['American Samoa', 'ASM', '1992', nan]
# error occurred: no such column: nan ['American Samoa', 'ASM', '1993', nan]
# error occurred: no such column: nan ['American Samoa', 'ASM', '1994', nan]
# error occurred: no such column: nan ['American Samoa', 'ASM', '1995', nan]
# error occurred: no such column: nan ['American Samoa', 'ASM', '1996', nan]
# error occurred: no such column: nan ['American Samoa', 'ASM', '1997', nan]
# error occurred: no such column: nan ['American Samoa', 'ASM', '1998', nan]
# error occurred: no such column: nan ['American Samoa', 'ASM', '1999', nan]
# error occurred: no such column: nan ['American Samoa', 'ASM', '2000', nan]
# error occurred: no such column: nan ['American Samoa', 'ASM', '2001', nan]
# error occurred: no such column: nan ['American Samoa', 'ASM', '2017', nan]
# error occurred: near ",": syntax error ['American Samoa', 'ASM', '\n', '\n']
# error occurred: no such column: nan ['Antigua and Barbuda', 'ATG', '1960', nan]
# error occurred: no such column: nan ['Antigua and Barbuda', 'ATG', '1961', nan]
# error occurred: no such column: nan ['Antigua and Barbuda', 'ATG', '1962', nan]
# error occurred: no such column: nan ['Antigua and Barbuda', 'ATG', '1963', nan]
# error occurred: no such column: nan ['Antigua and Barbuda', 'ATG', '1964', nan]
# error occurred: no such column: nan ['Antigua and Barbuda', 'ATG', '1965', nan]
# error occurred: no such column: nan ['Antigua and Barbuda', 'ATG', '1966', nan]
# error occurred: no such column: nan ['Antigua and Barbuda', 'ATG', '1967', nan]
# error occurred: no such column: nan ['Antigua and Barbuda', 'ATG', '1968', nan]
# error occurred: no such column: nan ['Antigua and Barbuda', 'ATG', '1969', nan]
# error occurred: no such column: nan ['Antigua and Barbuda', 'ATG', '1970', nan]
# error occurred: no such column: nan ['Antigua and Barbuda', 'ATG', '1971', nan]
# error occurred: no such column: nan ['Antigua and Barbuda', 'ATG', '1972', nan]
# error occurred: no such column: nan ['Antigua and Barbuda', 'ATG', '1973', nan]
# error occurred: no such column: nan ['Antigua and Barbuda', 'ATG', '1974', nan]
# error occurred: no such column: nan ['Antigua and Barbuda', 'ATG', '1975', nan]
# error occurred: no such column: nan ['Antigua and Barbuda', 'ATG', '1976', nan]
# error occurred: near ",": syntax error ['Antigua and Barbuda', 'ATG', '\n', '\n']
# error occurred: near ",": syntax error ['Australia', 'AUS', '\n', '\n']
# error occurred: near ",": syntax error ['Austria', 'AUT', '\n', '\n']
# error occurred: no such column: nan ['Azerbaijan', 'AZE', '1960', nan]
# error occurred: no such column: nan ['Azerbaijan', 'AZE', '1961', nan]
# error occurred: no such column: nan ['Azerbaijan', 'AZE', '1962', nan]
# error occurred: no such column: nan ['Azerbaijan', 'AZE', '1963', nan]
# error occurred: no such column: nan ['Azerbaijan', 'AZE', '1964', nan]
# error occurred: no such column: nan ['Azerbaijan', 'AZE', '1965', nan]
# error occurred: no such column: nan ['Azerbaijan', 'AZE', '1966', nan]
# error occurred: no such column: nan ['Azerbaijan', 'AZE', '1967', nan]
# error occurred: no such column: nan ['Azerbaijan', 'AZE', '1968', nan]
# error occurred: no such column: nan ['Azerbaijan', 'AZE', '1969', nan]
# error occurred: no such column: nan ['Azerbaijan', 'AZE', '1970', nan]
# error occurred: no such column: nan ['Azerbaijan', 'AZE', '1971', nan]
# error occurred: no such column: nan ['Azerbaijan', 'AZE', '1972', nan]
# error occurred: no such column: nan ['Azerbaijan', 'AZE', '1973', nan]
# error occurred: no such column: nan ['Azerbaijan', 'AZE', '1974', nan]
# error occurred: no such column: nan ['Azerbaijan', 'AZE', '1975', nan]
# error occurred: no such column: nan ['Azerbaijan', 'AZE', '1976', nan]
# error occurred: no such column: nan ['Azerbaijan', 'AZE', '1977', nan]
# error occurred: no such column: nan ['Azerbaijan', 'AZE', '1978', nan]
# error occurred: no such column: nan ['Azerbaijan', 'AZE', '1979', nan]
# error occurred: no such column: nan ['Azerbaijan', 'AZE', '1980', nan]
# error occurred: no such column: nan ['Azerbaijan', 'AZE', '1981', nan]
# error occurred: no such column: nan ['Azerbaijan', 'AZE', '1982', nan]
# error occurred: no such column: nan ['Azerbaijan', 'AZE', '1983', nan]
# error occurred: no such column: nan ['Azerbaijan', 'AZE', '1984', nan]
# error occurred: no such column: nan ['Azerbaijan', 'AZE', '1985', nan]
# error occurred: no such column: nan ['Azerbaijan', 'AZE', '1986', nan]
# error occurred: no such column: nan ['Azerbaijan', 'AZE', '1987', nan]
# error occurred: no such column: nan ['Azerbaijan', 'AZE', '1988', nan]
# error occurred: no such column: nan ['Azerbaijan', 'AZE', '1989', nan]
# error occurred: near ",": syntax error ['Azerbaijan', 'AZE', '\n', '\n']
# error occurred: near ",": syntax error ['Burundi', 'BDI', '\n', '\n']
# error occurred: near ",": syntax error ['Belgium', 'BEL', '\n', '\n']
# error occurred: near ",": syntax error ['Benin', 'BEN', '\n', '\n']
# error occurred: near ",": syntax error ['Burkina Faso', 'BFA', '\n', '\n']
# error occurred: near ",": syntax error ['Bangladesh', 'BGD', '\n', '\n']
# error occurred: no such column: nan ['Bulgaria', 'BGR', '1960', nan]
# error occurred: no such column: nan ['Bulgaria', 'BGR', '1961', nan]
# error occurred: no such column: nan ['Bulgaria', 'BGR', '1962', nan]
# error occurred: no such column: nan ['Bulgaria', 'BGR', '1963', nan]
# error occurred: no such column: nan ['Bulgaria', 'BGR', '1964', nan]
# error occurred: no such column: nan ['Bulgaria', 'BGR', '1965', nan]
# error occurred: no such column: nan ['Bulgaria', 'BGR', '1966', nan]
# error occurred: no such column: nan ['Bulgaria', 'BGR', '1967', nan]
# error occurred: no such column: nan ['Bulgaria', 'BGR', '1968', nan]
# error occurred: no such column: nan ['Bulgaria', 'BGR', '1969', nan]
# error occurred: no such column: nan ['Bulgaria', 'BGR', '1970', nan]
# error occurred: no such column: nan ['Bulgaria', 'BGR', '1971', nan]
# error occurred: no such column: nan ['Bulgaria', 'BGR', '1972', nan]
# error occurred: no such column: nan ['Bulgaria', 'BGR', '1973', nan]
# error occurred: no such column: nan ['Bulgaria', 'BGR', '1974', nan]
# error occurred: no such column: nan ['Bulgaria', 'BGR', '1975', nan]
# error occurred: no such column: nan ['Bulgaria', 'BGR', '1976', nan]
# error occurred: no such column: nan ['Bulgaria', 'BGR', '1977', nan]
# error occurred: no such column: nan ['Bulgaria', 'BGR', '1978', nan]
# error occurred: no such column: nan ['Bulgaria', 'BGR', '1979', nan]
# error occurred: near ",": syntax error ['Bulgaria', 'BGR', '\n', '\n']
# error occurred: no such column: nan ['Bahrain', 'BHR', '1960', nan]
# error occurred: no such column: nan ['Bahrain', 'BHR', '1961', nan]
# error occurred: no such column: nan ['Bahrain', 'BHR', '1962', nan]
# error occurred: no such column: nan ['Bahrain', 'BHR', '1963', nan]
# error occurred: no such column: nan ['Bahrain', 'BHR', '1964', nan]
# error occurred: no such column: nan ['Bahrain', 'BHR', '1965', nan]
# error occurred: no such column: nan ['Bahrain', 'BHR', '1966', nan]
# error occurred: no such column: nan ['Bahrain', 'BHR', '1967', nan]
# error occurred: no such column: nan ['Bahrain', 'BHR', '1968', nan]
# error occurred: no such column: nan ['Bahrain', 'BHR', '1969', nan]
# error occurred: no such column: nan ['Bahrain', 'BHR', '1970', nan]
# error occurred: no such column: nan ['Bahrain', 'BHR', '1971', nan]
# error occurred: no such column: nan ['Bahrain', 'BHR', '1972', nan]
# error occurred: no such column: nan ['Bahrain', 'BHR', '1973', nan]
# error occurred: no such column: nan ['Bahrain', 'BHR', '1974', nan]
# error occurred: no such column: nan ['Bahrain', 'BHR', '1975', nan]
# error occurred: no such column: nan ['Bahrain', 'BHR', '1976', nan]
# error occurred: no such column: nan ['Bahrain', 'BHR', '1977', nan]
# error occurred: no such column: nan ['Bahrain', 'BHR', '1978', nan]
# error occurred: no such column: nan ['Bahrain', 'BHR', '1979', nan]
# error occurred: near ",": syntax error ['Bahrain', 'BHR', '\n', '\n']
# error occurred: no such column: nan ['Bosnia and Herzegovina', 'BIH', '1960', nan]
# error occurred: no such column: nan ['Bosnia and Herzegovina', 'BIH', '1961', nan]
# error occurred: no such column: nan ['Bosnia and Herzegovina', 'BIH', '1962', nan]
# error occurred: no such column: nan ['Bosnia and Herzegovina', 'BIH', '1963', nan]
# error occurred: no such column: nan ['Bosnia and Herzegovina', 'BIH', '1964', nan]
# error occurred: no such column: nan ['Bosnia and Herzegovina', 'BIH', '1965', nan]
# error occurred: no such column: nan ['Bosnia and Herzegovina', 'BIH', '1966', nan]
# error occurred: no such column: nan ['Bosnia and Herzegovina', 'BIH', '1967', nan]
# error occurred: no such column: nan ['Bosnia and Herzegovina', 'BIH', '1968', nan]
# error occurred: no such column: nan ['Bosnia and Herzegovina', 'BIH', '1969', nan]
# error occurred: no such column: nan ['Bosnia and Herzegovina', 'BIH', '1970', nan]
# error occurred: no such column: nan ['Bosnia and Herzegovina', 'BIH', '1971', nan]
# error occurred: no such column: nan ['Bosnia and Herzegovina', 'BIH', '1972', nan]
# error occurred: no such column: nan ['Bosnia and Herzegovina', 'BIH', '1973', nan]
# error occurred: no such column: nan ['Bosnia and Herzegovina', 'BIH', '1974', nan]
# error occurred: no such column: nan ['Bosnia and Herzegovina', 'BIH', '1975', nan]
# error occurred: no such column: nan ['Bosnia and Herzegovina', 'BIH', '1976', nan]
# error occurred: no such column: nan ['Bosnia and Herzegovina', 'BIH', '1977', nan]
# error occurred: no such column: nan ['Bosnia and Herzegovina', 'BIH', '1978', nan]
# error occurred: no such column: nan ['Bosnia and Herzegovina', 'BIH', '1979', nan]
# error occurred: no such column: nan ['Bosnia and Herzegovina', 'BIH', '1980', nan]
# error occurred: no such column: nan ['Bosnia and Herzegovina', 'BIH', '1981', nan]
# error occurred: no such column: nan ['Bosnia and Herzegovina', 'BIH', '1982', nan]
# error occurred: no such column: nan ['Bosnia and Herzegovina', 'BIH', '1983', nan]
# error occurred: no such column: nan ['Bosnia and Herzegovina', 'BIH', '1984', nan]
# error occurred: no such column: nan ['Bosnia and Herzegovina', 'BIH', '1985', nan]
# error occurred: no such column: nan ['Bosnia and Herzegovina', 'BIH', '1986', nan]
# error occurred: no such column: nan ['Bosnia and Herzegovina', 'BIH', '1987', nan]
# error occurred: no such column: nan ['Bosnia and Herzegovina', 'BIH', '1988', nan]
# error occurred: no such column: nan ['Bosnia and Herzegovina', 'BIH', '1989', nan]
# error occurred: no such column: nan ['Bosnia and Herzegovina', 'BIH', '1990', nan]
# error occurred: no such column: nan ['Bosnia and Herzegovina', 'BIH', '1991', nan]
# error occurred: no such column: nan ['Bosnia and Herzegovina', 'BIH', '1992', nan]
# error occurred: no such column: nan ['Bosnia and Herzegovina', 'BIH', '1993', nan]
# error occurred: near ",": syntax error ['Bosnia and Herzegovina', 'BIH', '\n', '\n']
# error occurred: no such column: nan ['Belarus', 'BLR', '1960', nan]
# error occurred: no such column: nan ['Belarus', 'BLR', '1961', nan]
# error occurred: no such column: nan ['Belarus', 'BLR', '1962', nan]
# error occurred: no such column: nan ['Belarus', 'BLR', '1963', nan]
# error occurred: no such column: nan ['Belarus', 'BLR', '1964', nan]
# error occurred: no such column: nan ['Belarus', 'BLR', '1965', nan]
# error occurred: no such column: nan ['Belarus', 'BLR', '1966', nan]
# error occurred: no such column: nan ['Belarus', 'BLR', '1967', nan]
# error occurred: no such column: nan ['Belarus', 'BLR', '1968', nan]
# error occurred: no such column: nan ['Belarus', 'BLR', '1969', nan]
# error occurred: no such column: nan ['Belarus', 'BLR', '1970', nan]
# error occurred: no such column: nan ['Belarus', 'BLR', '1971', nan]
# error occurred: no such column: nan ['Belarus', 'BLR', '1972', nan]
# error occurred: no such column: nan ['Belarus', 'BLR', '1973', nan]
# error occurred: no such column: nan ['Belarus', 'BLR', '1974', nan]
# error occurred: no such column: nan ['Belarus', 'BLR', '1975', nan]
# error occurred: no such column: nan ['Belarus', 'BLR', '1976', nan]
# error occurred: no such column: nan ['Belarus', 'BLR', '1977', nan]
# error occurred: no such column: nan ['Belarus', 'BLR', '1978', nan]
# error occurred: no such column: nan ['Belarus', 'BLR', '1979', nan]
# error occurred: no such column: nan ['Belarus', 'BLR', '1980', nan]
# error occurred: no such column: nan ['Belarus', 'BLR', '1981', nan]
# error occurred: no such column: nan ['Belarus', 'BLR', '1982', nan]
# error occurred: no such column: nan ['Belarus', 'BLR', '1983', nan]
# error occurred: no such column: nan ['Belarus', 'BLR', '1984', nan]
# error occurred: no such column: nan ['Belarus', 'BLR', '1985', nan]
# error occurred: no such column: nan ['Belarus', 'BLR', '1986', nan]
# error occurred: no such column: nan ['Belarus', 'BLR', '1987', nan]
# error occurred: no such column: nan ['Belarus', 'BLR', '1988', nan]
# error occurred: no such column: nan ['Belarus', 'BLR', '1989', nan]
# error occurred: no such column: nan ['Belarus', 'BLR', '1991', nan]
# error occurred: no such column: nan ['Belarus', 'BLR', '1992', nan]
# error occurred: no such column: nan ['Belarus', 'BLR', '1993', nan]
# error occurred: near ",": syntax error ['Belarus', 'BLR', '\n', '\n']
# error occurred: near ",": syntax error ['Belize', 'BLZ', '\n', '\n']
# error occurred: no such column: nan ['Bermuda', 'BMU', '2014', nan]
# error occurred: no such column: nan ['Bermuda', 'BMU', '2015', nan]
# error occurred: no such column: nan ['Bermuda', 'BMU', '2016', nan]
# error occurred: no such column: nan ['Bermuda', 'BMU', '2017', nan]
# error occurred: near ",": syntax error ['Bermuda', 'BMU', '\n', '\n']
# error occurred: near ",": syntax error ['Bolivia', 'BOL', '\n', '\n']
# error occurred: no such column: nan ['Brazil', 'BRA', '1960', nan]
# error occurred: no such column: nan ['Brazil', 'BRA', '1961', nan]
# error occurred: no such column: nan ['Brazil', 'BRA', '1962', nan]
# error occurred: no such column: nan ['Brazil', 'BRA', '1963', nan]
# error occurred: no such column: nan ['Brazil', 'BRA', '1964', nan]
# error occurred: no such column: nan ['Brazil', 'BRA', '1965', nan]
# error occurred: no such column: nan ['Brazil', 'BRA', '1966', nan]
# error occurred: no such column: nan ['Brazil', 'BRA', '1967', nan]
# error occurred: no such column: nan ['Brazil', 'BRA', '1968', nan]
# error occurred: no such column: nan ['Brazil', 'BRA', '1969', nan]
# error occurred: no such column: nan ['Brazil', 'BRA', '1970', nan]
# error occurred: no such column: nan ['Brazil', 'BRA', '1971', nan]
# error occurred: no such column: nan ['Brazil', 'BRA', '1972', nan]
# error occurred: no such column: nan ['Brazil', 'BRA', '1973', nan]
# error occurred: no such column: nan ['Brazil', 'BRA', '1974', nan]
# error occurred: no such column: nan ['Brazil', 'BRA', '1975', nan]
# error occurred: no such column: nan ['Brazil', 'BRA', '1976', nan]
# error occurred: no such column: nan ['Brazil', 'BRA', '1977', nan]
# error occurred: no such column: nan ['Brazil', 'BRA', '1978', nan]
# error occurred: no such column: nan ['Brazil', 'BRA', '1979', nan]
# error occurred: no such column: nan ['Brazil', 'BRA', '1980', nan]
# error occurred: no such column: nan ['Brazil', 'BRA', '1981', nan]
# error occurred: near ",": syntax error ['Brazil', 'BRA', '\n', '\n']
# error occurred: no such column: nan ['Barbados', 'BRB', '1960', nan]
# error occurred: no such column: nan ['Barbados', 'BRB', '1961', nan]
# error occurred: no such column: nan ['Barbados', 'BRB', '1962', nan]
# error occurred: no such column: nan ['Barbados', 'BRB', '1963', nan]
# error occurred: no such column: nan ['Barbados', 'BRB', '1964', nan]
# error occurred: no such column: nan ['Barbados', 'BRB', '1965', nan]
# error occurred: no such column: nan ['Barbados', 'BRB', '1966', nan]
# error occurred: no such column: nan ['Barbados', 'BRB', '1967', nan]
# error occurred: no such column: nan ['Barbados', 'BRB', '1968', nan]
# error occurred: no such column: nan ['Barbados', 'BRB', '1969', nan]
# error occurred: no such column: nan ['Barbados', 'BRB', '1970', nan]
# error occurred: no such column: nan ['Barbados', 'BRB', '1971', nan]
# error occurred: no such column: nan ['Barbados', 'BRB', '1972', nan]
# error occurred: no such column: nan ['Barbados', 'BRB', '1973', nan]
# error occurred: near ",": syntax error ['Barbados', 'BRB', '\n', '\n']
# error occurred: no such column: nan ['Brunei Darussalam', 'BRN', '1960', nan]
# error occurred: no such column: nan ['Brunei Darussalam', 'BRN', '1961', nan]
# error occurred: no such column: nan ['Brunei Darussalam', 'BRN', '1962', nan]
# error occurred: no such column: nan ['Brunei Darussalam', 'BRN', '1963', nan]
# error occurred: no such column: nan ['Brunei Darussalam', 'BRN', '1964', nan]
# error occurred: near ",": syntax error ['Brunei Darussalam', 'BRN', '\n', '\n']
# error occurred: no such column: nan ['Bhutan', 'BTN', '1960', nan]
# error occurred: no such column: nan ['Bhutan', 'BTN', '1961', nan]
# error occurred: no such column: nan ['Bhutan', 'BTN', '1962', nan]
# error occurred: no such column: nan ['Bhutan', 'BTN', '1963', nan]
# error occurred: no such column: nan ['Bhutan', 'BTN', '1964', nan]
# error occurred: no such column: nan ['Bhutan', 'BTN', '1965', nan]
# error occurred: no such column: nan ['Bhutan', 'BTN', '1966', nan]
# error occurred: no such column: nan ['Bhutan', 'BTN', '1967', nan]
# error occurred: no such column: nan ['Bhutan', 'BTN', '1968', nan]
# error occurred: no such column: nan ['Bhutan', 'BTN', '1969', nan]
# error occurred: no such column: nan ['Bhutan', 'BTN', '1970', nan]
# error occurred: no such column: nan ['Bhutan', 'BTN', '1971', nan]
# error occurred: no such column: nan ['Bhutan', 'BTN', '1972', nan]
# error occurred: no such column: nan ['Bhutan', 'BTN', '1973', nan]
# error occurred: no such column: nan ['Bhutan', 'BTN', '1974', nan]
# error occurred: no such column: nan ['Bhutan', 'BTN', '1975', nan]
# error occurred: no such column: nan ['Bhutan', 'BTN', '1976', nan]
# error occurred: no such column: nan ['Bhutan', 'BTN', '1977', nan]
# error occurred: no such column: nan ['Bhutan', 'BTN', '1978', nan]
# error occurred: no such column: nan ['Bhutan', 'BTN', '1979', nan]
# error occurred: near ",": syntax error ['Bhutan', 'BTN', '\n', '\n']
# error occurred: near ",": syntax error ['Botswana', 'BWA', '\n', '\n']
# error occurred: near ",": syntax error ['Central African Republic', 'CAF', '\n', '\n']
# error occurred: near ",": syntax error ['Canada', 'CAN', '\n', '\n']
# error occurred: no such column: nan ['Switzerland', 'CHE', '1970', nan]
# error occurred: no such column: nan ['Switzerland', 'CHE', '1971', nan]
# error occurred: no such column: nan ['Switzerland', 'CHE', '1972', nan]
# error occurred: no such column: nan ['Switzerland', 'CHE', '1973', nan]
# error occurred: no such column: nan ['Switzerland', 'CHE', '1974', nan]
# error occurred: no such column: nan ['Switzerland', 'CHE', '1975', nan]
# error occurred: no such column: nan ['Switzerland', 'CHE', '1976', nan]
# error occurred: no such column: nan ['Switzerland', 'CHE', '1977', nan]
# error occurred: no such column: nan ['Switzerland', 'CHE', '1978', nan]
# error occurred: no such column: nan ['Switzerland', 'CHE', '1979', nan]
# error occurred: near ",": syntax error ['Switzerland', 'CHE', '\n', '\n']
# error occurred: no such column: nan ['Channel Islands', 'CHI', '1960', nan]
# error occurred: no such column: nan ['Channel Islands', 'CHI', '1961', nan]
# error occurred: no such column: nan ['Channel Islands', 'CHI', '1962', nan]
# error occurred: no such column: nan ['Channel Islands', 'CHI', '1963', nan]
# error occurred: no such column: nan ['Channel Islands', 'CHI', '1964', nan]
# error occurred: no such column: nan ['Channel Islands', 'CHI', '1965', nan]
# error occurred: no such column: nan ['Channel Islands', 'CHI', '1966', nan]
# error occurred: no such column: nan ['Channel Islands', 'CHI', '1967', nan]
# error occurred: no such column: nan ['Channel Islands', 'CHI', '1968', nan]
# error occurred: no such column: nan ['Channel Islands', 'CHI', '1969', nan]
# error occurred: no such column: nan ['Channel Islands', 'CHI', '1970', nan]
# error occurred: no such column: nan ['Channel Islands', 'CHI', '1971', nan]
# error occurred: no such column: nan ['Channel Islands', 'CHI', '1972', nan]
# error occurred: no such column: nan ['Channel Islands', 'CHI', '1973', nan]
# error occurred: no such column: nan ['Channel Islands', 'CHI', '1974', nan]
# error occurred: no such column: nan ['Channel Islands', 'CHI', '1975', nan]
# error occurred: no such column: nan ['Channel Islands', 'CHI', '1976', nan]
# error occurred: no such column: nan ['Channel Islands', 'CHI', '1977', nan]
# error occurred: no such column: nan ['Channel Islands', 'CHI', '1978', nan]
# error occurred: no such column: nan ['Channel Islands', 'CHI', '1979', nan]
# error occurred: no such column: nan ['Channel Islands', 'CHI', '1980', nan]
# error occurred: no such column: nan ['Channel Islands', 'CHI', '1981', nan]
# error occurred: no such column: nan ['Channel Islands', 'CHI', '1982', nan]
# error occurred: no such column: nan ['Channel Islands', 'CHI', '1983', nan]
# error occurred: no such column: nan ['Channel Islands', 'CHI', '1984', nan]
# error occurred: no such column: nan ['Channel Islands', 'CHI', '1985', nan]
# error occurred: no such column: nan ['Channel Islands', 'CHI', '1986', nan]
# error occurred: no such column: nan ['Channel Islands', 'CHI', '1987', nan]
# error occurred: no such column: nan ['Channel Islands', 'CHI', '1988', nan]
# error occurred: no such column: nan ['Channel Islands', 'CHI', '1989', nan]
# error occurred: no such column: nan ['Channel Islands', 'CHI', '1990', nan]
# error occurred: no such column: nan ['Channel Islands', 'CHI', '1991', nan]
# error occurred: no such column: nan ['Channel Islands', 'CHI', '1992', nan]
# error occurred: no such column: nan ['Channel Islands', 'CHI', '1993', nan]
# error occurred: no such column: nan ['Channel Islands', 'CHI', '1994', nan]
# error occurred: no such column: nan ['Channel Islands', 'CHI', '1995', nan]
# error occurred: no such column: nan ['Channel Islands', 'CHI', '1996', nan]
# error occurred: no such column: nan ['Channel Islands', 'CHI', '1997', nan]
# error occurred: no such column: nan ['Channel Islands', 'CHI', '2008', nan]
# error occurred: no such column: nan ['Channel Islands', 'CHI', '2009', nan]
# error occurred: no such column: nan ['Channel Islands', 'CHI', '2010', nan]
# error occurred: no such column: nan ['Channel Islands', 'CHI', '2011', nan]
# error occurred: no such column: nan ['Channel Islands', 'CHI', '2012', nan]
# error occurred: no such column: nan ['Channel Islands', 'CHI', '2013', nan]
# error occurred: no such column: nan ['Channel Islands', 'CHI', '2014', nan]
# error occurred: no such column: nan ['Channel Islands', 'CHI', '2015', nan]
# error occurred: no such column: nan ['Channel Islands', 'CHI', '2016', nan]
# error occurred: no such column: nan ['Channel Islands', 'CHI', '2017', nan]
# error occurred: near ",": syntax error ['Channel Islands', 'CHI', '\n', '\n']
# error occurred: near ",": syntax error ['Chile', 'CHL', '\n', '\n']
# error occurred: near ",": syntax error ['China', 'CHN', '\n', '\n']
# error occurred: near ",": syntax error ["Cote d'Ivoire", 'CIV', '\n', '\n']
# error occurred: near ",": syntax error ['Cameroon', 'CMR', '\n', '\n']
# error occurred: near ",": syntax error ['Colombia', 'COL', '\n', '\n']
# error occurred: no such column: nan ['Comoros', 'COM', '1960', nan]
# error occurred: no such column: nan ['Comoros', 'COM', '1961', nan]
# error occurred: no such column: nan ['Comoros', 'COM', '1962', nan]
# error occurred: no such column: nan ['Comoros', 'COM', '1963', nan]
# error occurred: no such column: nan ['Comoros', 'COM', '1964', nan]
# error occurred: no such column: nan ['Comoros', 'COM', '1965', nan]
# error occurred: no such column: nan ['Comoros', 'COM', '1966', nan]
# error occurred: no such column: nan ['Comoros', 'COM', '1967', nan]
# error occurred: no such column: nan ['Comoros', 'COM', '1968', nan]
# error occurred: no such column: nan ['Comoros', 'COM', '1969', nan]
# error occurred: no such column: nan ['Comoros', 'COM', '1970', nan]
# error occurred: no such column: nan ['Comoros', 'COM', '1971', nan]
# error occurred: no such column: nan ['Comoros', 'COM', '1972', nan]
# error occurred: no such column: nan ['Comoros', 'COM', '1973', nan]
# error occurred: no such column: nan ['Comoros', 'COM', '1974', nan]
# error occurred: no such column: nan ['Comoros', 'COM', '1975', nan]
# error occurred: no such column: nan ['Comoros', 'COM', '1976', nan]
# error occurred: no such column: nan ['Comoros', 'COM', '1977', nan]
# error occurred: no such column: nan ['Comoros', 'COM', '1978', nan]
# error occurred: no such column: nan ['Comoros', 'COM', '1979', nan]
# error occurred: near ",": syntax error ['Comoros', 'COM', '\n', '\n']
# error occurred: no such column: nan ['Cabo Verde', 'CPV', '1960', nan]
# error occurred: no such column: nan ['Cabo Verde', 'CPV', '1961', nan]
# error occurred: no such column: nan ['Cabo Verde', 'CPV', '1962', nan]
# error occurred: no such column: nan ['Cabo Verde', 'CPV', '1963', nan]
# error occurred: no such column: nan ['Cabo Verde', 'CPV', '1964', nan]
# error occurred: no such column: nan ['Cabo Verde', 'CPV', '1965', nan]
# error occurred: no such column: nan ['Cabo Verde', 'CPV', '1966', nan]
# error occurred: no such column: nan ['Cabo Verde', 'CPV', '1967', nan]
# error occurred: no such column: nan ['Cabo Verde', 'CPV', '1968', nan]
# error occurred: no such column: nan ['Cabo Verde', 'CPV', '1969', nan]
# error occurred: no such column: nan ['Cabo Verde', 'CPV', '1970', nan]
# error occurred: no such column: nan ['Cabo Verde', 'CPV', '1971', nan]
# error occurred: no such column: nan ['Cabo Verde', 'CPV', '1972', nan]
# error occurred: no such column: nan ['Cabo Verde', 'CPV', '1973', nan]
# error occurred: no such column: nan ['Cabo Verde', 'CPV', '1974', nan]
# error occurred: no such column: nan ['Cabo Verde', 'CPV', '1975', nan]
# error occurred: no such column: nan ['Cabo Verde', 'CPV', '1976', nan]
# error occurred: no such column: nan ['Cabo Verde', 'CPV', '1977', nan]
# error occurred: no such column: nan ['Cabo Verde', 'CPV', '1978', nan]
# error occurred: no such column: nan ['Cabo Verde', 'CPV', '1979', nan]
# error occurred: near ",": syntax error ['Cabo Verde', 'CPV', '\n', '\n']
# error occurred: near ",": syntax error ['Costa Rica', 'CRI', '\n', '\n']
# error occurred: no such column: nan ['Cuba', 'CUB', '1960', nan]
# error occurred: no such column: nan ['Cuba', 'CUB', '1961', nan]
# error occurred: no such column: nan ['Cuba', 'CUB', '1962', nan]
# error occurred: no such column: nan ['Cuba', 'CUB', '1963', nan]
# error occurred: no such column: nan ['Cuba', 'CUB', '1964', nan]
# error occurred: no such column: nan ['Cuba', 'CUB', '1965', nan]
# error occurred: no such column: nan ['Cuba', 'CUB', '1966', nan]
# error occurred: no such column: nan ['Cuba', 'CUB', '1967', nan]
# error occurred: no such column: nan ['Cuba', 'CUB', '1968', nan]
# error occurred: no such column: nan ['Cuba', 'CUB', '1969', nan]
# error occurred: no such column: nan ['Cuba', 'CUB', '2016', nan]
# error occurred: no such column: nan ['Cuba', 'CUB', '2017', nan]
# error occurred: near ",": syntax error ['Cuba', 'CUB', '\n', '\n']
# error occurred: no such column: nan ['Curacao', 'CUW', '1960', nan]
# error occurred: no such column: nan ['Curacao', 'CUW', '1961', nan]
# error occurred: no such column: nan ['Curacao', 'CUW', '1962', nan]
# error occurred: no such column: nan ['Curacao', 'CUW', '1963', nan]
# error occurred: no such column: nan ['Curacao', 'CUW', '1964', nan]
# error occurred: no such column: nan ['Curacao', 'CUW', '1965', nan]
# error occurred: no such column: nan ['Curacao', 'CUW', '1966', nan]
# error occurred: no such column: nan ['Curacao', 'CUW', '1967', nan]
# error occurred: no such column: nan ['Curacao', 'CUW', '1968', nan]
# error occurred: no such column: nan ['Curacao', 'CUW', '1969', nan]
# error occurred: no such column: nan ['Curacao', 'CUW', '1970', nan]
# error occurred: no such column: nan ['Curacao', 'CUW', '1971', nan]
# error occurred: no such column: nan ['Curacao', 'CUW', '1972', nan]
# error occurred: no such column: nan ['Curacao', 'CUW', '1973', nan]
# error occurred: no such column: nan ['Curacao', 'CUW', '1974', nan]
# error occurred: no such column: nan ['Curacao', 'CUW', '1975', nan]
# error occurred: no such column: nan ['Curacao', 'CUW', '1976', nan]
# error occurred: no such column: nan ['Curacao', 'CUW', '1977', nan]
# error occurred: no such column: nan ['Curacao', 'CUW', '1978', nan]
# error occurred: no such column: nan ['Curacao', 'CUW', '1979', nan]
# error occurred: no such column: nan ['Curacao', 'CUW', '1980', nan]
# error occurred: no such column: nan ['Curacao', 'CUW', '1981', nan]
# error occurred: no such column: nan ['Curacao', 'CUW', '1982', nan]
# error occurred: no such column: nan ['Curacao', 'CUW', '1983', nan]
# error occurred: no such column: nan ['Curacao', 'CUW', '1984', nan]
# error occurred: no such column: nan ['Curacao', 'CUW', '1985', nan]
# error occurred: no such column: nan ['Curacao', 'CUW', '1986', nan]
# error occurred: no such column: nan ['Curacao', 'CUW', '1987', nan]
# error occurred: no such column: nan ['Curacao', 'CUW', '1988', nan]
# error occurred: no such column: nan ['Curacao', 'CUW', '1989', nan]
# error occurred: no such column: nan ['Curacao', 'CUW', '1990', nan]
# error occurred: no such column: nan ['Curacao', 'CUW', '1991', nan]
# error occurred: no such column: nan ['Curacao', 'CUW', '1992', nan]
# error occurred: no such column: nan ['Curacao', 'CUW', '1993', nan]
# error occurred: no such column: nan ['Curacao', 'CUW', '1994', nan]
# error occurred: no such column: nan ['Curacao', 'CUW', '1995', nan]
# error occurred: no such column: nan ['Curacao', 'CUW', '1996', nan]
# error occurred: no such column: nan ['Curacao', 'CUW', '1997', nan]
# error occurred: no such column: nan ['Curacao', 'CUW', '1998', nan]
# error occurred: no such column: nan ['Curacao', 'CUW', '1999', nan]
# error occurred: no such column: nan ['Curacao', 'CUW', '2000', nan]
# error occurred: no such column: nan ['Curacao', 'CUW', '2001', nan]
# error occurred: no such column: nan ['Curacao', 'CUW', '2002', nan]
# error occurred: no such column: nan ['Curacao', 'CUW', '2003', nan]
# error occurred: no such column: nan ['Curacao', 'CUW', '2004', nan]
# error occurred: no such column: nan ['Curacao', 'CUW', '2005', nan]
# error occurred: no such column: nan ['Curacao', 'CUW', '2006', nan]
# error occurred: no such column: nan ['Curacao', 'CUW', '2007', nan]
# error occurred: no such column: nan ['Curacao', 'CUW', '2008', nan]
# error occurred: no such column: nan ['Curacao', 'CUW', '2009', nan]
# error occurred: no such column: nan ['Curacao', 'CUW', '2010', nan]
# error occurred: no such column: nan ['Curacao', 'CUW', '2011', nan]
# error occurred: no such column: nan ['Curacao', 'CUW', '2012', nan]
# error occurred: no such column: nan ['Curacao', 'CUW', '2013', nan]
# error occurred: no such column: nan ['Curacao', 'CUW', '2014', nan]
# error occurred: no such column: nan ['Curacao', 'CUW', '2015', nan]
# error occurred: no such column: nan ['Curacao', 'CUW', '2016', nan]
# error occurred: no such column: nan ['Curacao', 'CUW', '2017', nan]
# error occurred: near ",": syntax error ['Curacao', 'CUW', '\n', '\n']
# error occurred: no such column: nan ['Cayman Islands', 'CYM', '1960', nan]
# error occurred: no such column: nan ['Cayman Islands', 'CYM', '1961', nan]
# error occurred: no such column: nan ['Cayman Islands', 'CYM', '1962', nan]
# error occurred: no such column: nan ['Cayman Islands', 'CYM', '1963', nan]
# error occurred: no such column: nan ['Cayman Islands', 'CYM', '1964', nan]
# error occurred: no such column: nan ['Cayman Islands', 'CYM', '1965', nan]
# error occurred: no such column: nan ['Cayman Islands', 'CYM', '1966', nan]
# error occurred: no such column: nan ['Cayman Islands', 'CYM', '1967', nan]
# error occurred: no such column: nan ['Cayman Islands', 'CYM', '1968', nan]
# error occurred: no such column: nan ['Cayman Islands', 'CYM', '1969', nan]
# error occurred: no such column: nan ['Cayman Islands', 'CYM', '1970', nan]
# error occurred: no such column: nan ['Cayman Islands', 'CYM', '1971', nan]
# error occurred: no such column: nan ['Cayman Islands', 'CYM', '1972', nan]
# error occurred: no such column: nan ['Cayman Islands', 'CYM', '1973', nan]
# error occurred: no such column: nan ['Cayman Islands', 'CYM', '1974', nan]
# error occurred: no such column: nan ['Cayman Islands', 'CYM', '1975', nan]
# error occurred: no such column: nan ['Cayman Islands', 'CYM', '1976', nan]
# error occurred: no such column: nan ['Cayman Islands', 'CYM', '1977', nan]
# error occurred: no such column: nan ['Cayman Islands', 'CYM', '1978', nan]
# error occurred: no such column: nan ['Cayman Islands', 'CYM', '1979', nan]
# error occurred: no such column: nan ['Cayman Islands', 'CYM', '1980', nan]
# error occurred: no such column: nan ['Cayman Islands', 'CYM', '1981', nan]
# error occurred: no such column: nan ['Cayman Islands', 'CYM', '1982', nan]
# error occurred: no such column: nan ['Cayman Islands', 'CYM', '1983', nan]
# error occurred: no such column: nan ['Cayman Islands', 'CYM', '1984', nan]
# error occurred: no such column: nan ['Cayman Islands', 'CYM', '1985', nan]
# error occurred: no such column: nan ['Cayman Islands', 'CYM', '1986', nan]
# ...
# error occurred: no such column: nan ['Ukraine', 'UKR', '1991', nan]
# error occurred: near ",": syntax error ['Ukraine', 'UKR', '\n', '\n']
# error occurred: near ",": syntax error ['Uruguay', 'URY', '\n', '\n']
# error occurred: near ",": syntax error ['United States', 'USA', '\n', '\n']
# error occurred: no such column: nan ['Uzbekistan', 'UZB', '1960', nan]
# error occurred: no such column: nan ['Uzbekistan', 'UZB', '1961', nan]
# error occurred: no such column: nan ['Uzbekistan', 'UZB', '1962', nan]
# error occurred: no such column: nan ['Uzbekistan', 'UZB', '1963', nan]
# error occurred: no such column: nan ['Uzbekistan', 'UZB', '1964', nan]
# error occurred: no such column: nan ['Uzbekistan', 'UZB', '1965', nan]
# error occurred: no such column: nan ['Uzbekistan', 'UZB', '1966', nan]
# error occurred: no such column: nan ['Uzbekistan', 'UZB', '1967', nan]
# error occurred: no such column: nan ['Uzbekistan', 'UZB', '1968', nan]
# error occurred: no such column: nan ['Uzbekistan', 'UZB', '1969', nan]
# error occurred: no such column: nan ['Uzbekistan', 'UZB', '1970', nan]
# error occurred: no such column: nan ['Uzbekistan', 'UZB', '1971', nan]
# error occurred: no such column: nan ['Uzbekistan', 'UZB', '1972', nan]
# error occurred: no such column: nan ['Uzbekistan', 'UZB', '1973', nan]
# error occurred: no such column: nan ['Uzbekistan', 'UZB', '1974', nan]
# error occurred: no such column: nan ['Uzbekistan', 'UZB', '1975', nan]
# error occurred: no such column: nan ['Uzbekistan', 'UZB', '1976', nan]
# error occurred: no such column: nan ['Uzbekistan', 'UZB', '1977', nan]
# error occurred: no such column: nan ['Uzbekistan', 'UZB', '1978', nan]
# error occurred: no such column: nan ['Uzbekistan', 'UZB', '1979', nan]
# error occurred: no such column: nan ['Uzbekistan', 'UZB', '1980', nan]
# error occurred: no such column: nan ['Uzbekistan', 'UZB', '1981', nan]
# error occurred: no such column: nan ['Uzbekistan', 'UZB', '1982', nan]
# error occurred: no such column: nan ['Uzbekistan', 'UZB', '1983', nan]
# error occurred: no such column: nan ['Uzbekistan', 'UZB', '1984', nan]
# error occurred: no such column: nan ['Uzbekistan', 'UZB', '1985', nan]
# error occurred: no such column: nan ['Uzbekistan', 'UZB', '1986', nan]
# error occurred: no such column: nan ['Uzbekistan', 'UZB', '1987', nan]
# error occurred: no such column: nan ['Uzbekistan', 'UZB', '1988', nan]
# error occurred: no such column: nan ['Uzbekistan', 'UZB', '1989', nan]
# error occurred: near ",": syntax error ['Uzbekistan', 'UZB', '\n', '\n']
# error occurred: near ",": syntax error ['St. Vincent and the Grenadines', 'VCT', '\n', '\n']
# error occurred: no such column: nan ['British Virgin Islands', 'VGB', '1960', nan]
# error occurred: no such column: nan ['British Virgin Islands', 'VGB', '1961', nan]
# error occurred: no such column: nan ['British Virgin Islands', 'VGB', '1962', nan]
# error occurred: no such column: nan ['British Virgin Islands', 'VGB', '1963', nan]
# error occurred: no such column: nan ['British Virgin Islands', 'VGB', '1964', nan]
# error occurred: no such column: nan ['British Virgin Islands', 'VGB', '1965', nan]
# error occurred: no such column: nan ['British Virgin Islands', 'VGB', '1966', nan]
# error occurred: no such column: nan ['British Virgin Islands', 'VGB', '1967', nan]
# error occurred: no such column: nan ['British Virgin Islands', 'VGB', '1968', nan]
# error occurred: no such column: nan ['British Virgin Islands', 'VGB', '1969', nan]
# error occurred: no such column: nan ['British Virgin Islands', 'VGB', '1970', nan]
# error occurred: no such column: nan ['British Virgin Islands', 'VGB', '1971', nan]
# error occurred: no such column: nan ['British Virgin Islands', 'VGB', '1972', nan]
# error occurred: no such column: nan ['British Virgin Islands', 'VGB', '1973', nan]
# error occurred: no such column: nan ['British Virgin Islands', 'VGB', '1974', nan]
# error occurred: no such column: nan ['British Virgin Islands', 'VGB', '1975', nan]
# error occurred: no such column: nan ['British Virgin Islands', 'VGB', '1976', nan]
# error occurred: no such column: nan ['British Virgin Islands', 'VGB', '1977', nan]
# error occurred: no such column: nan ['British Virgin Islands', 'VGB', '1978', nan]
# error occurred: no such column: nan ['British Virgin Islands', 'VGB', '1979', nan]
# error occurred: no such column: nan ['British Virgin Islands', 'VGB', '1980', nan]
# error occurred: no such column: nan ['British Virgin Islands', 'VGB', '1981', nan]
# error occurred: no such column: nan ['British Virgin Islands', 'VGB', '1982', nan]
# error occurred: no such column: nan ['British Virgin Islands', 'VGB', '1983', nan]
# error occurred: no such column: nan ['British Virgin Islands', 'VGB', '1984', nan]
# error occurred: no such column: nan ['British Virgin Islands', 'VGB', '1985', nan]
# error occurred: no such column: nan ['British Virgin Islands', 'VGB', '1986', nan]
# error occurred: no such column: nan ['British Virgin Islands', 'VGB', '1987', nan]
# error occurred: no such column: nan ['British Virgin Islands', 'VGB', '1988', nan]
# error occurred: no such column: nan ['British Virgin Islands', 'VGB', '1989', nan]
# error occurred: no such column: nan ['British Virgin Islands', 'VGB', '1990', nan]
# error occurred: no such column: nan ['British Virgin Islands', 'VGB', '1991', nan]
# error occurred: no such column: nan ['British Virgin Islands', 'VGB', '1992', nan]
# error occurred: no such column: nan ['British Virgin Islands', 'VGB', '1993', nan]
# error occurred: no such column: nan ['British Virgin Islands', 'VGB', '1994', nan]
# error occurred: no such column: nan ['British Virgin Islands', 'VGB', '1995', nan]
# error occurred: no such column: nan ['British Virgin Islands', 'VGB', '1996', nan]
# error occurred: no such column: nan ['British Virgin Islands', 'VGB', '1997', nan]
# error occurred: no such column: nan ['British Virgin Islands', 'VGB', '1998', nan]
# error occurred: no such column: nan ['British Virgin Islands', 'VGB', '1999', nan]
# error occurred: no such column: nan ['British Virgin Islands', 'VGB', '2000', nan]
# error occurred: no such column: nan ['British Virgin Islands', 'VGB', '2001', nan]
# error occurred: no such column: nan ['British Virgin Islands', 'VGB', '2002', nan]
# error occurred: no such column: nan ['British Virgin Islands', 'VGB', '2003', nan]
# error occurred: no such column: nan ['British Virgin Islands', 'VGB', '2004', nan]
# error occurred: no such column: nan ['British Virgin Islands', 'VGB', '2005', nan]
# error occurred: no such column: nan ['British Virgin Islands', 'VGB', '2006', nan]
# error occurred: no such column: nan ['British Virgin Islands', 'VGB', '2007', nan]
# error occurred: no such column: nan ['British Virgin Islands', 'VGB', '2008', nan]
# error occurred: no such column: nan ['British Virgin Islands', 'VGB', '2009', nan]
# error occurred: no such column: nan ['British Virgin Islands', 'VGB', '2010', nan]
# error occurred: no such column: nan ['British Virgin Islands', 'VGB', '2011', nan]
# error occurred: no such column: nan ['British Virgin Islands', 'VGB', '2012', nan]
# error occurred: no such column: nan ['British Virgin Islands', 'VGB', '2013', nan]
# error occurred: no such column: nan ['British Virgin Islands', 'VGB', '2014', nan]
# error occurred: no such column: nan ['British Virgin Islands', 'VGB', '2015', nan]
# error occurred: no such column: nan ['British Virgin Islands', 'VGB', '2016', nan]
# error occurred: no such column: nan ['British Virgin Islands', 'VGB', '2017', nan]
# error occurred: near ",": syntax error ['British Virgin Islands', 'VGB', '\n', '\n']
# error occurred: no such column: nan ['Virgin Islands (U.S.)', 'VIR', '1994', nan]
# error occurred: no such column: nan ['Virgin Islands (U.S.)', 'VIR', '1995', nan]
# error occurred: no such column: nan ['Virgin Islands (U.S.)', 'VIR', '1996', nan]
# error occurred: no such column: nan ['Virgin Islands (U.S.)', 'VIR', '1997', nan]
# error occurred: no such column: nan ['Virgin Islands (U.S.)', 'VIR', '1998', nan]
# error occurred: no such column: nan ['Virgin Islands (U.S.)', 'VIR', '1999', nan]
# error occurred: no such column: nan ['Virgin Islands (U.S.)', 'VIR', '2000', nan]
# error occurred: no such column: nan ['Virgin Islands (U.S.)', 'VIR', '2001', nan]
# error occurred: no such column: nan ['Virgin Islands (U.S.)', 'VIR', '2016', nan]
# error occurred: no such column: nan ['Virgin Islands (U.S.)', 'VIR', '2017', nan]
# error occurred: near ",": syntax error ['Virgin Islands (U.S.)', 'VIR', '\n', '\n']
# error occurred: no such column: nan ['Vietnam', 'VNM', '1960', nan]
# error occurred: no such column: nan ['Vietnam', 'VNM', '1961', nan]
# error occurred: no such column: nan ['Vietnam', 'VNM', '1962', nan]
# error occurred: no such column: nan ['Vietnam', 'VNM', '1963', nan]
# error occurred: no such column: nan ['Vietnam', 'VNM', '1964', nan]
# error occurred: no such column: nan ['Vietnam', 'VNM', '1965', nan]
# error occurred: no such column: nan ['Vietnam', 'VNM', '1966', nan]
# error occurred: no such column: nan ['Vietnam', 'VNM', '1967', nan]
# error occurred: no such column: nan ['Vietnam', 'VNM', '1968', nan]
# error occurred: no such column: nan ['Vietnam', 'VNM', '1969', nan]
# error occurred: no such column: nan ['Vietnam', 'VNM', '1970', nan]
# error occurred: no such column: nan ['Vietnam', 'VNM', '1971', nan]
# error occurred: no such column: nan ['Vietnam', 'VNM', '1972', nan]
# error occurred: no such column: nan ['Vietnam', 'VNM', '1973', nan]
# error occurred: no such column: nan ['Vietnam', 'VNM', '1974', nan]
# error occurred: no such column: nan ['Vietnam', 'VNM', '1975', nan]
# error occurred: no such column: nan ['Vietnam', 'VNM', '1976', nan]
# error occurred: no such column: nan ['Vietnam', 'VNM', '1977', nan]
# error occurred: no such column: nan ['Vietnam', 'VNM', '1978', nan]
# error occurred: no such column: nan ['Vietnam', 'VNM', '1979', nan]
# error occurred: no such column: nan ['Vietnam', 'VNM', '1980', nan]
# error occurred: no such column: nan ['Vietnam', 'VNM', '1981', nan]
# error occurred: no such column: nan ['Vietnam', 'VNM', '1982', nan]
# error occurred: no such column: nan ['Vietnam', 'VNM', '1983', nan]
# error occurred: no such column: nan ['Vietnam', 'VNM', '1984', nan]
# error occurred: near ",": syntax error ['Vietnam', 'VNM', '\n', '\n']
# error occurred: no such column: nan ['Vanuatu', 'VUT', '1960', nan]
# error occurred: no such column: nan ['Vanuatu', 'VUT', '1961', nan]
# error occurred: no such column: nan ['Vanuatu', 'VUT', '1962', nan]
# error occurred: no such column: nan ['Vanuatu', 'VUT', '1963', nan]
# error occurred: no such column: nan ['Vanuatu', 'VUT', '1964', nan]
# error occurred: no such column: nan ['Vanuatu', 'VUT', '1965', nan]
# error occurred: no such column: nan ['Vanuatu', 'VUT', '1966', nan]
# error occurred: no such column: nan ['Vanuatu', 'VUT', '1967', nan]
# error occurred: no such column: nan ['Vanuatu', 'VUT', '1968', nan]
# error occurred: no such column: nan ['Vanuatu', 'VUT', '1969', nan]
# error occurred: no such column: nan ['Vanuatu', 'VUT', '1970', nan]
# error occurred: no such column: nan ['Vanuatu', 'VUT', '1971', nan]
# error occurred: no such column: nan ['Vanuatu', 'VUT', '1972', nan]
# error occurred: no such column: nan ['Vanuatu', 'VUT', '1973', nan]
# error occurred: no such column: nan ['Vanuatu', 'VUT', '1974', nan]
# error occurred: no such column: nan ['Vanuatu', 'VUT', '1975', nan]
# error occurred: no such column: nan ['Vanuatu', 'VUT', '1976', nan]
# error occurred: no such column: nan ['Vanuatu', 'VUT', '1977', nan]
# error occurred: no such column: nan ['Vanuatu', 'VUT', '1978', nan]
# error occurred: near ",": syntax error ['Vanuatu', 'VUT', '\n', '\n']
# error occurred: no such column: nan ['Samoa', 'WSM', '1960', nan]
# error occurred: no such column: nan ['Samoa', 'WSM', '1961', nan]
# error occurred: no such column: nan ['Samoa', 'WSM', '1962', nan]
# error occurred: no such column: nan ['Samoa', 'WSM', '1963', nan]
# error occurred: no such column: nan ['Samoa', 'WSM', '1964', nan]
# error occurred: no such column: nan ['Samoa', 'WSM', '1965', nan]
# error occurred: no such column: nan ['Samoa', 'WSM', '1966', nan]
# error occurred: no such column: nan ['Samoa', 'WSM', '1967', nan]
# error occurred: no such column: nan ['Samoa', 'WSM', '1968', nan]
# error occurred: no such column: nan ['Samoa', 'WSM', '1969', nan]
# error occurred: no such column: nan ['Samoa', 'WSM', '1970', nan]
# error occurred: no such column: nan ['Samoa', 'WSM', '1971', nan]
# error occurred: no such column: nan ['Samoa', 'WSM', '1972', nan]
# error occurred: no such column: nan ['Samoa', 'WSM', '1973', nan]
# error occurred: no such column: nan ['Samoa', 'WSM', '1974', nan]
# error occurred: no such column: nan ['Samoa', 'WSM', '1975', nan]
# error occurred: no such column: nan ['Samoa', 'WSM', '1976', nan]
# error occurred: no such column: nan ['Samoa', 'WSM', '1977', nan]
# error occurred: no such column: nan ['Samoa', 'WSM', '1978', nan]
# error occurred: no such column: nan ['Samoa', 'WSM', '1979', nan]
# error occurred: no such column: nan ['Samoa', 'WSM', '1980', nan]
# error occurred: no such column: nan ['Samoa', 'WSM', '1981', nan]
# error occurred: near ",": syntax error ['Samoa', 'WSM', '\n', '\n']
# error occurred: no such column: nan ['Kosovo', 'XKX', '1960', nan]
# error occurred: no such column: nan ['Kosovo', 'XKX', '1961', nan]
# error occurred: no such column: nan ['Kosovo', 'XKX', '1962', nan]
# error occurred: no such column: nan ['Kosovo', 'XKX', '1963', nan]
# error occurred: no such column: nan ['Kosovo', 'XKX', '1964', nan]
# error occurred: no such column: nan ['Kosovo', 'XKX', '1965', nan]
# error occurred: no such column: nan ['Kosovo', 'XKX', '1966', nan]
# error occurred: no such column: nan ['Kosovo', 'XKX', '1967', nan]
# error occurred: no such column: nan ['Kosovo', 'XKX', '1968', nan]
# error occurred: no such column: nan ['Kosovo', 'XKX', '1969', nan]
# error occurred: no such column: nan ['Kosovo', 'XKX', '1970', nan]
# error occurred: no such column: nan ['Kosovo', 'XKX', '1971', nan]
# error occurred: no such column: nan ['Kosovo', 'XKX', '1972', nan]
# error occurred: no such column: nan ['Kosovo', 'XKX', '1973', nan]
# error occurred: no such column: nan ['Kosovo', 'XKX', '1974', nan]
# error occurred: no such column: nan ['Kosovo', 'XKX', '1975', nan]
# error occurred: no such column: nan ['Kosovo', 'XKX', '1976', nan]
# error occurred: no such column: nan ['Kosovo', 'XKX', '1977', nan]
# error occurred: no such column: nan ['Kosovo', 'XKX', '1978', nan]
# error occurred: no such column: nan ['Kosovo', 'XKX', '1979', nan]
# error occurred: no such column: nan ['Kosovo', 'XKX', '1980', nan]
# error occurred: no such column: nan ['Kosovo', 'XKX', '1981', nan]
# error occurred: no such column: nan ['Kosovo', 'XKX', '1982', nan]
# error occurred: no such column: nan ['Kosovo', 'XKX', '1983', nan]
# error occurred: no such column: nan ['Kosovo', 'XKX', '1984', nan]
# error occurred: no such column: nan ['Kosovo', 'XKX', '1985', nan]
# error occurred: no such column: nan ['Kosovo', 'XKX', '1986', nan]
# error occurred: no such column: nan ['Kosovo', 'XKX', '1987', nan]
# error occurred: no such column: nan ['Kosovo', 'XKX', '1988', nan]
# error occurred: no such column: nan ['Kosovo', 'XKX', '1989', nan]
# error occurred: no such column: nan ['Kosovo', 'XKX', '1990', nan]
# error occurred: no such column: nan ['Kosovo', 'XKX', '1991', nan]
# error occurred: no such column: nan ['Kosovo', 'XKX', '1992', nan]
# error occurred: no such column: nan ['Kosovo', 'XKX', '1993', nan]
# error occurred: no such column: nan ['Kosovo', 'XKX', '1994', nan]
# error occurred: no such column: nan ['Kosovo', 'XKX', '1995', nan]
# error occurred: no such column: nan ['Kosovo', 'XKX', '1996', nan]
# error occurred: no such column: nan ['Kosovo', 'XKX', '1997', nan]
# error occurred: no such column: nan ['Kosovo', 'XKX', '1998', nan]
# error occurred: no such column: nan ['Kosovo', 'XKX', '1999', nan]
# error occurred: near ",": syntax error ['Kosovo', 'XKX', '\n', '\n']
# error occurred: near ",": syntax error ['South Africa', 'ZAF', '\n', '\n']
# error occurred: near ",": syntax error ['Zambia', 'ZMB', '\n', '\n']
# error occurred: near ",": syntax error ['Zimbabwe', 'ZWE', '\n', '\n']

# %%
# Execute this code cell to output the values in the gdp table
# You do not need to change anything in this cell

# connect to the database
# the database file will be worldbank.db
# note that sqlite3 will create this database file if it does not exist already
conn = sqlite3.connect('worldbank.db')

# get a cursor
cur = conn.cursor()

# create the test table including project_id as a primary key
df = pd.read_sql("SELECT * FROM gdp", con=conn)

conn.commit()
conn.close()

df
# Out:
#       countryname countrycode  year           gdp
# 0           Aruba         ABW  1994  1.330168e+09
# 1           Aruba         ABW  1995  1.320670e+09
# 2           Aruba         ABW  1996  1.379888e+09
# 3           Aruba         ABW  1997  1.531844e+09
# 4           Aruba         ABW  1998  1.665363e+09
# 5           Aruba         ABW  1999  1.722799e+09
# 6           Aruba         ABW  2000  1.873453e+09
# 7           Aruba         ABW  2001  1.920263e+09
# 8           Aruba         ABW  2002  1.941095e+09
# 9           Aruba         ABW  2003  2.021302e+09
# 10          Aruba         ABW  2004  2.228279e+09
# 11          Aruba         ABW  2005  2.331006e+09
# 12          Aruba         ABW  2006  2.421475e+09
# 13          Aruba         ABW  2007  2.623726e+09
# 14          Aruba         ABW  2008  2.791961e+09
# 15          Aruba         ABW  2009  2.498933e+09
# 16          Aruba         ABW  2010  2.467704e+09
# 17          Aruba         ABW  2011  2.584464e+09
# 18    Afghanistan         AFG  1960  5.377778e+08
# 19    Afghanistan         AFG  1961  5.488889e+08
# 20    Afghanistan         AFG  1962  5.466667e+08
# 21    Afghanistan         AFG  1963  7.511112e+08
# 22    Afghanistan         AFG  1964  8.000000e+08
# 23    Afghanistan         AFG  1965  1.006667e+09
# 24    Afghanistan         AFG  1966  1.400000e+09
# 25    Afghanistan         AFG  1967  1.673333e+09
# 26    Afghanistan         AFG  1968  1.373333e+09
# 27    Afghanistan         AFG  1969  1.408889e+09
# 28    Afghanistan         AFG  1970  1.748887e+09
# 29    Afghanistan         AFG  1971  1.831109e+09
# ...           ...         ...   ...           ...
# 8684     Zimbabwe         ZWE  1988  7.814784e+09
# 8685     Zimbabwe         ZWE  1989  8.286323e+09
# 8686     Zimbabwe         ZWE  1990  8.783817e+09
# 8687     Zimbabwe         ZWE  1991  8.641482e+09
# 8688     Zimbabwe         ZWE  1992  6.751472e+09
# 8689     Zimbabwe         ZWE  1993  6.563813e+09
# 8690     Zimbabwe         ZWE  1994  6.890675e+09
# 8691     Zimbabwe         ZWE  1995  7.111271e+09
# 8692     Zimbabwe         ZWE  1996  8.553147e+09
# 8693     Zimbabwe         ZWE  1997  8.529572e+09
# 8694     Zimbabwe         ZWE  1998  6.401968e+09
# 8695     Zimbabwe         ZWE  1999  6.858013e+09
# 8696     Zimbabwe         ZWE  2000  6.689958e+09
# 8697     Zimbabwe         ZWE  2001  6.777385e+09
# 8698     Zimbabwe         ZWE  2002  6.342116e+09
# 8699     Zimbabwe         ZWE  2003  5.727592e+09
# 8700     Zimbabwe         ZWE  2004  5.805598e+09
# 8701     Zimbabwe         ZWE  2005  5.755215e+09
# 8702     Zimbabwe         ZWE  2006  5.443896e+09
# 8703     Zimbabwe         ZWE  2007  5.291950e+09
# 8704     Zimbabwe         ZWE  2008  4.415703e+09
# 8705     Zimbabwe         ZWE  2009  8.621574e+09
# 8706     Zimbabwe         ZWE  2010  1.014186e+10
# 8707     Zimbabwe         ZWE  2011  1.209845e+10
# 8708     Zimbabwe         ZWE  2012  1.424249e+10
# 8709     Zimbabwe         ZWE  2013  1.545177e+10
# 8710     Zimbabwe         ZWE  2014  1.589105e+10
# 8711     Zimbabwe         ZWE  2015  1.630467e+10
# 8712     Zimbabwe         ZWE  2016  1.661996e+10
# 8713     Zimbabwe         ZWE  2017  1.784582e+10
#
# [8714 rows x 4 columns]

# %% [markdown]
# # Conclusion
#
# ETL Pipelines involve extracting data from one source, which in this case was a csv file, then transforming the data into a more usable form, and finally loading the data somewhere else.
#
# The purpose of ETL pipelines is to make data more usable and accessible.
